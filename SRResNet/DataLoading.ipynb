# %%
import torch
import torchvision
import matplotlib.pyplot as plt
#from torch.utils.tensorboard import SummaryWriter
from torch.utils.data import DataLoader
from tqdm import tqdm

#from critics import FCCritic
#from generators import FCGenerator
from dataset import FacesDataSet

import torchvision.transforms as transforms

IMG_SIZE_LR = 64
IMG_SIZE_HR = 256
BATCH_SIZE = 10
NUM_WORKERS = 8

def train():
    data_set = FacesDataSet(IMG_SIZE_LR, IMG_SIZE_HR)

    data_loader = DataLoader(data_set,
                            batch_size=BATCH_SIZE,
                            shuffle=True,
                            pin_memory=True,
                            num_workers=NUM_WORKERS,
                            drop_last=True)

    #print(data_loader[0].shape)
    batch = next(iter(data_loader))
    #print(batch[0])
    print(batch[0][0])
    print(batch[1][0])
    print(batch[0][0].shape)
    print(batch[1][0].shape)
    print(len(batch))
    #plt.imshow(batch[0][0])

if __name__ == "__main__":
    train()
# Out:
# tensor([[[0.9020, 0.9020, 0.8980,  ..., 0.7686, 0.7961, 0.8039],
#          [0.9176, 0.9176, 0.9137,  ..., 0.8039, 0.8196, 0.8196],
#          [0.9294, 0.9294, 0.9255,  ..., 0.8314, 0.8353, 0.8353],
#          ...,
#          [0.1373, 0.1608, 0.2196,  ..., 0.9176, 0.9176, 0.9176],
#          [0.1608, 0.1804, 0.1529,  ..., 0.9137, 0.9176, 0.9176],
#          [0.1725, 0.1843, 0.1373,  ..., 0.9176, 0.9176, 0.9176]],
#
#         [[0.8863, 0.8863, 0.8824,  ..., 0.7255, 0.7529, 0.7608],
#          [0.9059, 0.9059, 0.9020,  ..., 0.7647, 0.7804, 0.7843],
#          [0.9255, 0.9255, 0.9216,  ..., 0.8000, 0.8039, 0.8039],
#          ...,
#          [0.0941, 0.1176, 0.1765,  ..., 0.9216, 0.9216, 0.9216],
#          [0.1176, 0.1373, 0.1098,  ..., 0.9176, 0.9216, 0.9216],
#          [0.1294, 0.1412, 0.0941,  ..., 0.9216, 0.9216, 0.9216]],
#
#         [[0.8706, 0.8706, 0.8667,  ..., 0.7020, 0.7294, 0.7412],
#          [0.8941, 0.8941, 0.8902,  ..., 0.7451, 0.7647, 0.7647],
# ...

# %%
data_set1 = FacesDataSet(256)
image1 = data_set1.__getitem__(0)
plt.imshow(image1)

# %%
image = data_set.__getitem__(500)
plt.imshow(image)

# %%
image1 = data_set1.__getitem__(500)
plt.imshow(image1)
